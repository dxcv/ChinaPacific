# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from portfolio import Portfolio
# %matplotlib inline 

## read in data
ret_df_raw= pd.read_excel( io= 'Data/cipc data.xlsx', sheetname= 'Data_Input', index_col=0)

ret_df= ret_df_raw[['US_RE', 
                   'US_PE',
                   'US_CORP',
                   'SP500',
                   'Rusell2000',
                   'EAFE',
                   'EM']]
                   #'USGOVT10Y']]
ret_df_cov= ret_df.cov()

UniverseProperty= {}

from sklearn.covariance import LedoitWolf
LW= LedoitWolf( ).fit(ret_df)
LW_alpha= LW.shrinkage_

LW_cov= pd.DataFrame(LW.covariance_)*4
LW_cov.index= ret_df_cov.index
LW_cov.columns= ret_df_cov.columns
LW_vol= np.sqrt(np.diag(LW_cov))
LW_corr= pd.DataFrame( np.dot( np.dot( np.diag(1/ LW_vol), LW_cov), np.diag(1/LW_vol)) , 
                      index= LW_cov.index, columns= LW_cov.columns)
CMA_passive_geo= np.array( [7, 8.8, 2.75, 7.21, 8.06, 7.07, 8.03 ])/100
CMA_active_geo= CMA_passive_geo+ np.array( [0,0, 0.5, 1,1,1,1])/100
CMA_active_arith= CMA_active_geo+ 0.5* LW_vol**2
LW_cov_active= LW_cov+ np.diag([0, 0, 4, 9,9,9,9])/10000
LW_vol_active= np.sqrt(np.diag(LW_cov_active))


# the asset universe properties
UniverseProperty['asset_name']= LW_cov.index.tolist()
UniverseProperty['asset_count']= LW_cov.shape[0]
UniverseProperty['LW_cov']= LW_cov
UniverseProperty['LW_vol']= LW_vol
UniverseProperty['LW_corr']= LW_corr
UniverseProperty['CMA_active_geo']= CMA_active_geo
UniverseProperty['CMA_active_arith']= CMA_active_arith
UniverseProperty['LW_cov_active']= LW_cov_active
UniverseProperty['LW_vol_active']= LW_vol_active


# Portfolios

portfolios= {}
portfolios['EqualWeights']= Portfolio(asset_ret= UniverseProperty['CMA_active_geo'], 
                                      asset_cov= UniverseProperty['LW_cov_active'], 
                                      weight= [1/UniverseProperty['asset_count']]* UniverseProperty['asset_count'])
portfolios['Peer']= Portfolio( asset_ret= UniverseProperty['CMA_active_geo'],
                             asset_cov= UniverseProperty['LW_cov_active'], 
                             weight= [0.14,0.29,0.05,0.24,0.03,0.21,0.05])

# solve ERC

def temp_ERC_func(w, sigma):
    A= np.diag( w)
    B= np.diag( np.dot( sigma, w))
    C= np.diag( np.dot( A, B))/ np.dot( np.dot( w, sigma), w)- np.ones( w.size )* 1/ w.size
    return np.dot( C, C)

from scipy.optimize import minimize 

ERC_opt_res= minimize( temp_ERC_func, 
                 x0= portfolios['EqualWeights'].weight ,
                 args= LW_cov,
                 method= 'Powell',
                 options= {'disp': True},
                 tol= 1e-16)

weight_erc = ERC_opt_res.x/ np.sum( ERC_opt_res.x)
portfolios['ERC']= Portfolio( asset_ret= UniverseProperty['CMA_active_geo'],
                            asset_cov= UniverseProperty['LW_cov_active'],
                            weight= weight_erc)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 11
#          Function evaluations: 1281

# %% [markdown]
# ## Frontier Construction

# %%
def frontier_obj(w, sigma):
    return (np.dot(  np.dot( w, sigma), w)* .5)

def frontier_obj_der( w, sigma): 
    return (np.dot( w, sigma))


frontier_cons0= {'type': 'eq',
          'fun': lambda w: np.array( [np.sum(w)-1] ) ,
          'jac': lambda w: np.array( [1]*w.size)}

frontier_uncons={}

for target_ret in np.linspace(0.045, 0.08, 100 ): 
    frontier_cons1= {'type': 'ineq', 
                'fun': lambda w: np.dot(w, UniverseProperty['CMA_active_geo'])- target_ret,
                'jac': lambda w: UniverseProperty['CMA_active_geo']} 

    cons= (frontier_cons0 # fully invested 
          , frontier_cons1 # return requirement 
          )
    
    
    # unconstrained opt
    MV_opt_1= minimize( frontier_obj, 
                    x0= portfolios['EqualWeights'].weight, 
                    args= UniverseProperty['LW_cov_active'], 
                    jac= frontier_obj_der ,
                    method= 'SLSQP',
                    options= {'disp': True, 'maxiter': 1000},
                    constraints= cons, 
                    bounds= [[0, None]]* UniverseProperty['asset_count'],
                    tol= 1e-10)  # long only constrain
    
    frontier_uncons[target_ret]= Portfolio( asset_ret= UniverseProperty['CMA_active_geo'],
                                         asset_cov= UniverseProperty['LW_cov_active'],
                                         weight= MV_opt_1.x)
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0014577770818944482
#             Iterations: 23
#             Function evaluations: 23
#             Gradient evaluations: 23
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0014577770818944482
#             Iterations: 23
#             Function evaluations: 23
#             Gradient evaluations: 23
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0014577770818944482
#             Iterations: 23
#             Function evaluations: 23
#             Gradient evaluations: 23
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0014577770818944482
#             Iterations: 23
#             Function evaluations: 23
#             Gradient evaluations: 23
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0014577770818944482
#             Iterations: 23
#             Function evaluations: 23
#             Gradient evaluations: 23
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0014577770818944482
#             Iterations: 23
#             Function evaluations: 23
#             Gradient evaluations: 23
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0014579915550259946
#             Iterations: 23
#             Function evaluations: 23
#             Gradient evaluations: 23
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0014589714118107282
#             Iterations: 23
#             Function evaluations: 23
#             Gradient evaluations: 23
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0014607444149733364
#             Iterations: 23
#             Function evaluations: 23
#             Gradient evaluations: 23
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.00146331056451382
#             Iterations: 23
#             Function evaluations: 23
#             Gradient evaluations: 23
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.001466669860432178
#             Iterations: 23
#             Function evaluations: 23
#             Gradient evaluations: 23
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.001470822302728411
#             Iterations: 22
#             Function evaluations: 22
#             Gradient evaluations: 22
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0014757678914025193
#             Iterations: 22
#             Function evaluations: 22
#             Gradient evaluations: 22
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0014815066264545025
#             Iterations: 22
#             Function evaluations: 22
#             Gradient evaluations: 22
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0014880385078843606
#             Iterations: 22
#             Function evaluations: 22
#             Gradient evaluations: 22
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.001495363535692094
#             Iterations: 22
#             Function evaluations: 22
#             Gradient evaluations: 22
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0015034817098777018
#             Iterations: 22
#             Function evaluations: 22
#             Gradient evaluations: 22
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0015123930774840603
#             Iterations: 22
#             Function evaluations: 22
#             Gradient evaluations: 22
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0015220975423436414
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0015325951132162882
#             Iterations: 20
#             Function evaluations: 20
#             Gradient evaluations: 20
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0015438858703988845
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0015559697764738678
#             Iterations:
# C:\Anaconda3\lib\site-packages\scipy\optimize\slsqp.py:341: RuntimeWarning: invalid value encountered in greater
#   bnderr = bnds[:, 0] > bnds[:, 1]
#  17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0015688468289267263
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0015825170277574594
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.001596980372966067
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0016122368645525508
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0016282865025169083
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.001645129286859141
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0016627652175792503
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0016811942946772327
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.001700416518153091
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0017204318880068242
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0017412404042384322
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0017628420668479158
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0017852368758352734
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0018084248312005063
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0018324059339145577
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.001857180183463284
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0018827475769115835
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.001909108117161027
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0019362618412777039
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0019642086373289126
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.001992944427471515
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0020224580759151418
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0020527489880245078
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0020838171637996097
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0021156626032404497
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0021482853063470283
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.002181685273119341
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.002215862503557395
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.002250816997661186
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0022865487554307143
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0023230577858819827
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0023603440619669827
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.002398407610733724
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0024372484286057836
#             Iterations: 21
#             Function evaluations: 21
#             Gradient evaluations: 21
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.002476866499264421
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0025172618390283774
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.002558434442458065
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0026003843095534955
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.002643111440314661
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0026866158347415656
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0027308974928342065
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0027759564145925873
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0028217926000167035
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0028684060491065574
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.002915796761862151
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.00296396473828348
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.003012909978370548
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0030626324821233517
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.003113132249541896
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.003164409280626176
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0032164635753761943
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0032692951337919465
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0033229039558734445
#             Iterations: 20
#             Function evaluations: 20
#             Gradient evaluations: 20
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0033772900416206724
#             Iterations: 20
#             Function evaluations: 20
#             Gradient evaluations: 20
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.003432453391033643
#             Iterations: 20
#             Function evaluations: 20
#             Gradient evaluations: 20
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0034883940041123456
#             Iterations: 20
#             Function evaluations: 20
#             Gradient evaluations: 20
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0035451118808567904
#             Iterations: 20
#             Function evaluations: 20
#             Gradient evaluations: 20
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.003602607021266972
#             Iterations: 20
#             Function evaluations: 20
#             Gradient evaluations: 20
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0036608794253428856
#             Iterations: 20
#             Function evaluations: 20
#             Gradient evaluations: 20
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.003719929093084545
#             Iterations: 20
#             Function evaluations: 20
#             Gradient evaluations: 20
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.00377975602449194
#             Iterations: 20
#             Function evaluations: 20
#             Gradient evaluations: 20
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.003840360219565076
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0039017416783039436
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0039639004007085525
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004026836386778888
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004090549636514972
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004155040149916793
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004220307926984347
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004286352967717644
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004353175272116676
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004420774840181446
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004490815422326915
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004568683768842172
#             Iterations: 15
#             Function evaluations: 15
#             Gradient evaluations: 15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004654791737661518
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004749139328784959
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004851726542212495
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004962490471947843
#             Iterations: 21
#             Function evaluations: 21
#             Gradient evaluations: 21
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005080457766293831
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19

# %%
frontier_uncons_NoCorp={}



for target_ret in np.linspace(0.072, 0.089, 100): 
    frontier_cons1= {'type': 'ineq', 
                'fun': lambda w: np.dot(w, UniverseProperty['CMA_active_geo'])- target_ret,
                'jac': lambda w: UniverseProperty['CMA_active_geo']} 

    cons= (frontier_cons0 # fully invested 
          , frontier_cons1 # return requirement 
          )
    
    initial_guess= np.ones(UniverseProperty['asset_count'])* 1/UniverseProperty['asset_count']
    initial_guess[2]=0
    # unconstrained opt
    MV_opt_2= minimize( frontier_obj, 
                    x0= initial_guess, 
                    args= UniverseProperty['LW_cov_active'], 
                    jac= frontier_obj_der ,
                    method= 'SLSQP',
                    options= {'disp': True, 'maxiter':1000},
                    constraints= cons, 
                    bounds= [[0, None], [0, None], [0, 1e-15]]+ [[0, None]]* ( UniverseProperty['asset_count']- 3),
                    tol= 1e-8)  # long only constrain
    
    frontier_uncons_NoCorp[target_ret]= Portfolio( asset_ret= UniverseProperty['CMA_active_geo'],
                                         asset_cov= UniverseProperty['LW_cov_active'],
                                         weight= MV_opt_2.x)
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.00416077477782325
#             Iterations: 22
#             Function evaluations: 22
#             Gradient evaluations: 22
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.00416077477782325
#             Iterations: 22
#             Function evaluations: 22
#             Gradient evaluations: 22
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.00416077477782325
#             Iterations: 22
#             Function evaluations: 22
#             Gradient evaluations: 22
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.00416077477782325
#             Iterations: 22
#             Function evaluations: 22
#             Gradient evaluations: 22
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.00416077477782325
#             Iterations: 22
#             Function evaluations: 22
#             Gradient evaluations: 22
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.00416077477782325
#             Iterations: 22
#             Function evaluations: 22
#             Gradient evaluations: 22
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.00416077477782325
#             Iterations: 22
#             Function evaluations: 22
#             Gradient evaluations: 22
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.00416077477782325
#             Iterations: 22
#             Function evaluations: 22
#             Gradient evaluations: 22
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.00416077477782325
#             Iterations: 22
#             Function evaluations: 22
#             Gradient evaluations: 22
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.00416077477782325
#             Iterations: 22
#             Function evaluations: 22
#             Gradient evaluations: 22
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.00416077477782325
#             Iterations: 22
#             Function evaluations: 22
#             Gradient evaluations: 22
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.00416077477782325
#             Iterations: 22
#             Function evaluations: 22
#             Gradient evaluations: 22
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value:
# C:\Anaconda3\lib\site-packages\scipy\optimize\slsqp.py:341: RuntimeWarning: invalid value encountered in greater
#   bnderr = bnds[:, 0] > bnds[:, 1]
#  0.00416077477782325
#             Iterations: 22
#             Function evaluations: 22
#             Gradient evaluations: 22
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.00416077477782325
#             Iterations: 22
#             Function evaluations: 22
#             Gradient evaluations: 22
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.00416077477782325
#             Iterations: 22
#             Function evaluations: 22
#             Gradient evaluations: 22
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.00416077477782325
#             Iterations: 22
#             Function evaluations: 22
#             Gradient evaluations: 22
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004160809771823081
#             Iterations: 22
#             Function evaluations: 22
#             Gradient evaluations: 22
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004162217253253992
#             Iterations: 13
#             Function evaluations: 13
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004165658553804278
#             Iterations: 13
#             Function evaluations: 13
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004170677119325241
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0041778542188837114
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004186975196683722
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004198040052725267
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004211048787008353
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004226001399532972
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004242897890299129
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004261738259306824
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004282522506556058
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004305250632046825
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0043299226357791315
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004356538517752974
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004385098277968353
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004415601916425272
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004448049433123725
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004482440828063714
#             Iterations: 15
#             Function evaluations: 15
#             Gradient evaluations: 15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004518776101245241
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004557055252668307
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004597278282332912
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004639445190239051
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004683555976386728
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004729610640775942
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004777609183406688
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004827551604278981
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004879437903392803
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0049332674935867946
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004988852275923084
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005046794151951213
#             Iterations: 13
#             Function evaluations: 13
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005104875779664407
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005165320944708794
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005227387166612556
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005291074445375673
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.00535638278099816
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005423312173501386
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005491862622821221
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.00556207554993603
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005634089274135771
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005707914902912942
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005783552429771836
#             Iterations: 17
#             Function evaluations: 18
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005861004755394287
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005940264572365925
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.006021336427357675
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.006104221565322092
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.006188947402836362
#             Iterations: 11
#             Function evaluations: 11
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.006275476491720835
#             Iterations: 11
#             Function evaluations: 11
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.006363748393597358
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.006453881141149787
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.006545825791099224
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.006639582343445663
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.006735150798189102
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.006832531155329555
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0069317234148670095
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.007032727576801457
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.007135543641132919
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.007240171607861364
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.007346611476986838
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.007454863248509297
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.007564926922428764
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.007676802498745246
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.007790489977458714
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0079059893585692
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0080233006420767
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.008142423827981181
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.008263358916282673
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.008386105906981174
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.008510664800076664
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.008637035595569175
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.008765218293458677
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.008895212893745206
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.009027019396428712
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.009160637801509244
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.009296068108986756
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.009433310318861276
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.009572364431132801
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.009713230445801326
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.009855908362866877
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.010000398182329433
#             Iterations: 13
#             Function evaluations: 13
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.010161085778709472
#             Iterations: 13
#             Function evaluations: 13
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.010407928331626966
#             Iterations: 12
#             Function evaluations: 12
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.01075022712873975
#             Iterations: 11
#             Function evaluations: 11
#             Gradient evaluations: 11
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.011187943745062967
#             Iterations: 11
#             Function evaluations: 11
#             Gradient evaluations: 11

# %%
frontier_cons= {}

for target_ret in np.linspace(0.065, 0.08, 100 ): 
    frontier_cons1= {'type': 'ineq', 
                'fun': lambda w: np.dot(w, UniverseProperty['CMA_active_geo'])- target_ret,
                'jac': lambda w: UniverseProperty['CMA_active_geo']} 

    cons= (frontier_cons0 # fully invested 
          , frontier_cons1 # return requirement 
          )
    
    # constrained opt 
    MV_opt_3= minimize( frontier_obj, 
                    x0= portfolios['EqualWeights'].weight, 
                    args= UniverseProperty['LW_cov_active'], 
                    jac= frontier_obj_der ,
                    method= 'SLSQP',
                    options= {'disp': True, 'maxiter':1000},
                    constraints= cons, 
                    bounds= [[0,0.3]]* UniverseProperty['asset_count'],
                    tol= 1e-12)  # long only+ concentration constrain
    
    frontier_cons[target_ret]=   Portfolio( asset_ret= UniverseProperty['CMA_active_geo'], 
                                        asset_cov= UniverseProperty['LW_cov_active'],
                                        weight= MV_opt_3.x)
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0026858324918957958
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0026858324918957953
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.002685832491895796
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.002699710399635359
#             Iterations: 13
#             Function evaluations: 13
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0027219862184357808
#             Iterations: 12
#             Function evaluations: 12
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.002744502543939999
#             Iterations: 12
#             Function evaluations: 12
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0027672593761480136
#             Iterations: 13
#             Function evaluations: 13
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.00279025671505982
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.00281349456067542
#             Iterations: 15
#             Function evaluations: 15
#             Gradient evaluations: 15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.002836972912994817
#             Iterations: 15
#             Function evaluations: 15
#             Gradient evaluations: 15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.002860691772018006
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0028846511377449884
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.002908851010175768
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0029332913893103368
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0029579722751487073
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0029828936676908665
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.003008055566936819
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0030334579728865676
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.003059100885540112
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0030849843048974504
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0031111082309585817
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.003137472663723507
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0031640776031922235
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.003190923049364738
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0032180090022410454
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.003245335461821148
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.003272902428105046
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0033007099010927375
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0033287578807842206
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.003357046367179497
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0033855753602785713
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0034143448600814424
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0034433548665881034
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.003472605379798558
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.003502096399712809
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0035318279263308514
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0035617999596526907
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.003592012499678317
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0036224655464077455
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.00365315909984098
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.00368409315997799
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0037152677268187948
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.003746682800363392
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0037783383806117934
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0038102344675639797
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0038423710612199725
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0038747481615797478
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.00390736297475546
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.003940212415360801
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.003973296481519347
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0040066151732310535
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004040167894741237
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004073952869882339
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004107969980316777
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0041422192260533565
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004176700607078633
#             Iterations: 20
#             Function evaluations: 20
#             Gradient evaluations: 20
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0042114141233807745
#             Iterations: 19
#             Function evaluations: 20
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004246359775186631
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004281537562072715
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004316947484082325
#             Iterations: 20
#             Function evaluations: 20
#             Gradient evaluations: 20
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004352589541972519
#             Iterations: 21
#             Function evaluations: 21
#             Gradient evaluations: 21
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004388463734348265
#             Iterations: 21
#             Function evaluations: 22
#             Gradient evaluations: 21
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004424570062760768
#             Iterations: 20
#             Function evaluations: 20
#             Gradient evaluations: 20
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004460908525892377
#             Iterations: 20
#             Function evaluations: 20
#             Gradient evaluations: 20
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0044974791244482394
#             Iterations: 20
#             Function evaluations: 21
#             Gradient evaluations: 20
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004534281858401265
#             Iterations: 21
#             Function evaluations: 21
#             Gradient evaluations: 21
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004571316727647955
#             Iterations: 21
#             Function evaluations: 21
#             Gradient evaluations: 21
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004608583732187912
#             Iterations: 21
#             Function evaluations: 21
#             Gradient evaluations: 21
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004646082872020344
#             Iterations: 21
#             Function evaluations: 21
#             Gradient evaluations: 21
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004683814147146055
#             Iterations: 21
#             Function evaluations: 21
#             Gradient evaluations: 21
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004721777557565046
#             Iterations: 20
#             Function evaluations: 21
#             Gradient evaluations: 20
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004759973103277345
#             Iterations: 20
#             Function evaluations: 21
#             Gradient evaluations: 20
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004798400784703473
#             Iterations: 20
#             Function evaluations: 20
#             Gradient evaluations: 20
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004837060600923588
#             Iterations: 20
#             Function evaluations: 20
#             Gradient evaluations: 20
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004875952552336675
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0049150766391511695
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0049544328612892595
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.004994021218735748
#             Iterations: 20
#             Function evaluations: 20
#             Gradient evaluations: 20
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005033841711555961
#             Iterations: 20
#             Function evaluations: 20
#             Gradient evaluations: 20
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005073894848143938
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.00511419990343481
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005154766703381797
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005195595247863966
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.00523668553688132
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005278037570433857
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.00531965134852158
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0053615268711444805
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005403664138302566
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.00544606314999584
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0054887239062242875
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0055316464069879254
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005574830652286747
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005618276642120749
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005661984376489935
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005705953855394305
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.00575018507883386
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005794678046808589
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.00583943275931851
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005884449216363614
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005929727417943901
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17

# %%
frontier_cons_NoCorp= {}

for target_ret in np.linspace(0.073, 0.087, 100 ): 
    frontier_cons1= {'type': 'ineq', 
                'fun': lambda w: np.dot(w, UniverseProperty['CMA_active_geo'])- target_ret,
                'jac': lambda w: UniverseProperty['CMA_active_geo']} 

    cons= (frontier_cons0 # fully invested 
          , frontier_cons1 # return requirement 
          )
    
    # constrained opt 
    initial_guess= np.ones(UniverseProperty['asset_count'])* 1/UniverseProperty['asset_count']
    initial_guess[2]=0
    MV_opt_4= minimize( frontier_obj, 
                    x0= initial_guess, 
                    args= UniverseProperty['LW_cov_active'], 
                    jac= frontier_obj_der ,
                    method= 'SLSQP',
                    options= {'disp': True, 'maxiter': 1000},
                    constraints= cons, 
                    bounds= [[0,0.3], [0, 0.3], [0, 1e-15]]+ [[0, 0.3]]* ( UniverseProperty['asset_count']-3) ,
                    tol= 1e-12)  # long only+ concentration constrain
    
    frontier_cons_NoCorp[target_ret]=   Portfolio( asset_ret= UniverseProperty['CMA_active_geo'], 
                                        asset_cov= UniverseProperty['LW_cov_active'],
                                        weight= MV_opt_4.x)
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909799
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.005999742164909803
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.006019898883903388
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.006049572523018299
#             Iterations: 15
#             Function evaluations: 15
#             Gradient evaluations: 15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.006083988034971336
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.00612314541976249
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.006167044677391778
#             Iterations: 13
#             Function evaluations: 13
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0062156858078591904
#             Iterations: 15
#             Function evaluations: 15
#             Gradient evaluations: 15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0062690688111647136
#             Iterations: 15
#             Function evaluations: 15
#             Gradient evaluations: 15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0063267241623529424
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.006387925081290643
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.006452664334455685
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.006520941921848096
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.00659275784346797
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.006668112099314968
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.006747004689389444
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.00682943561369128
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.006915404872220457
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.007004912464977002
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.007097958391960892
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.007194542653172156
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.007294665248610743
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.007398345040384398
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.007507614456050235
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.00761976683310663
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.007734510057028581
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.007851844127816065
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.007971769045469113
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.008094284809987721
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.008219391421371841
#             Iterations: 15
#             Function evaluations: 15
#             Gradient evaluations: 15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.00834708887962152
#             Iterations: 15
#             Function evaluations: 15
#             Gradient evaluations: 15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.008477377184736776
#             Iterations: 15
#             Function evaluations: 15
#             Gradient evaluations: 15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.008610256336717562
#             Iterations: 15
#             Function evaluations: 15
#             Gradient evaluations: 15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.008745726335563885
#             Iterations: 15
#             Function evaluations: 15
#             Gradient evaluations: 15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.008883787181275787
#             Iterations: 15
#             Function evaluations: 15
#             Gradient evaluations: 15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.00902443887385323
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.009167681413296203
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.009313514799604749
#             Iterations: 13
#             Function evaluations: 13
#             Gradient evaluations: 13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.009461939032778829
#             Iterations: 12
#             Function evaluations: 12
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.009612954112818463
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.009766560039723643
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.009922756813494383
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.010081544434130663
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.010242922901632506
#             Iterations: 15
#             Function evaluations: 15
#             Gradient evaluations: 15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.010406892215999856
#             Iterations: 15
#             Function evaluations: 15
#             Gradient evaluations: 15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.010573452377232815
#             Iterations: 15
#             Function evaluations: 15
#             Gradient evaluations: 15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.01074260338533128
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.010914345240295305
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.011088677942124862
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.011265601490820006
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.011445115886380669
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14

# %%
fig= plt.figure()

frontier_uncons_pair= [[x.expected_return, x.volatility, x.weight] for x in frontier_uncons.values()]
frontier_uncons_pair.sort(key= lambda x: x[0])
plt.scatter(x= [x[1] for x in frontier_uncons_pair], y= [x[0] for x in frontier_uncons_pair], 
            marker='o', c= 'pink', s=10, label= 'long only')

frontier_uncons_NoCorp_pair= [[x.expected_return, x.volatility, x.weight] for x in frontier_uncons_NoCorp.values()]
frontier_uncons_NoCorp_pair.sort(key= lambda x : x[0])
plt.scatter( x= [x[1] for x in frontier_uncons_NoCorp_pair], y = [x[0] for x in frontier_uncons_NoCorp_pair], 
           marker= 'o', c= 'orange', s=10, label= 'long only(No Corp)')


frontier_cons_pair= [[x.expected_return, x.volatility, x.weight] for x in frontier_cons.values()]
frontier_cons_pair.sort(key= lambda x : x[0])
plt.scatter(x= [x[1] for x in frontier_cons_pair], y= [x[0] for x in frontier_cons_pair], 
            marker= '*', c= 'blue' , s=10, label= 'long only and constrained')

frontier_cons_NoCorp_pair= [[x.expected_return, x.volatility, x.weight] for x in frontier_cons_NoCorp.values()]
frontier_cons_NoCorp_pair.sort(key= lambda x: x[0])
plt.scatter(x= [x[1] for x in frontier_cons_NoCorp_pair], y= [x[0] for x in frontier_cons_NoCorp_pair], 
           marker= '*', c= 'red', s=10, label= 'long only and constrained(No Corp)')
plt.legend()

# %%
# For display purpose 


writter= pd.ExcelWriter('output_wz3.xlsx')
tmp_df1= pd.DataFrame(   [[x[0], x[1]]+ x[2].tolist()  for x in frontier_uncons_pair], 
                      columns= ['ExpectedRet', 'vol']+ UniverseProperty['asset_name']  )
tmp_df2= pd.DataFrame(  [[x[0], x[1]]+ x[2].tolist()  for x in frontier_uncons_NoCorp_pair], 
                     columns=  ['ExpectedRet', 'vol']+ UniverseProperty['asset_name'])

tmp_df3= pd.DataFrame(  [[x[0], x[1]]+ x[2].tolist()  for x in frontier_cons_pair], 
                     columns=  ['ExpectedRet', 'vol']+ UniverseProperty['asset_name'])
tmp_df4= pd.DataFrame(  [[x[0], x[1]]+ x[2].tolist()  for x in frontier_cons_NoCorp_pair], 
                     columns=  ['ExpectedRet', 'vol']+ UniverseProperty['asset_name'])

tmp_df1.to_excel( writter, 'UNCONS')
tmp_df2.to_excel( writter, 'UNCONS_NoCorp')
tmp_df3.to_excel( writter, 'CONS')
tmp_df4.to_excel( writter, 'CONS_NoCorp')

writter.save()

# %% [markdown]
# ## Peer Implied Return

# %%
risk_free= 179/10000
gamma= 3.5

UniverseProperty['impliedExpectedReturn_peer']= portfolios['Peer'].implied_ExpectedReturn(gamma= gamma, risk_free= risk_free)
UniverseProperty['impliedExpectedReturn_peer']
# Out:
# [0.03611070102341608,
#  0.06990940231831162,
#  0.021894619613667034,
#  0.07866845038644708,
#  0.09027125071422017,
#  0.08762225902860993,
#  0.10082597594278384]

# %% [markdown]
# ## Combined Return (BL) and Frontier
